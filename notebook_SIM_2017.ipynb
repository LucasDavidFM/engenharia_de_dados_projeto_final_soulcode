# %% [markdown]
# ##**IMPORTANDO AS BIBLIOTECAS/MÓDULOS**

# %% [markdown]
# * gcsfs -> conexão com o GCP
# * pymongo -> Conexão com o MongoDB
# * pandas -> manipulação e análise de dados
# * pyspark -> framework para processar grandes quantidades de dados
# * fsspec -> projeto para fornecer uma interface Python unificada para sistemas de arquivos locais, remotos e incorporados e armazenamento de bytes.
# * pandera -> validação de schema

# %%
pip install gcsfs
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting gcsfs
#   Downloading gcsfs-2022.5.0-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: google-cloud-storage in /usr/local/lib/python3.7/dist-packages (from gcsfs) (1.18.1)
# Requirement already satisfied: google-auth-oauthlib in /usr/local/lib/python3.7/dist-packages (from gcsfs) (0.4.6)
# Requirement already satisfied: google-auth>=1.2 in /usr/local/lib/python3.7/dist-packages (from gcsfs) (1.35.0)
# Requirement already satisfied: decorator>4.1.2 in /usr/local/lib/python3.7/dist-packages (from gcsfs) (4.4.2)
# Collecting fsspec==2022.5.0
#   Downloading fsspec-2022.5.0-py3-none-any.whl (140 kB)
#      |████████████████████████████████| 140 kB 7.5 MB/s
# Collecting aiohttp<4
#   Downloading aiohttp-3.8.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 52.6 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from gcsfs) (2.23.0)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from aiohttp<4->gcsfs) (4.2.0)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.7.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (271 kB)
#      |████████████████████████████████| 271 kB 56.4 MB/s
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp<4->gcsfs) (2.0.12)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
#      |████████████████████████████████| 144 kB 49.7 MB/s
# Collecting asynctest==0.13.0
#   Downloading asynctest-0.13.0-py3-none-any.whl (26 kB)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp<4->gcsfs) (21.4.0)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (94 kB)
#      |████████████████████████████████| 94 kB 715 kB/s
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.2->gcsfs) (1.15.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.2->gcsfs) (4.8)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.2->gcsfs) (57.4.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.2->gcsfs) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.2->gcsfs) (0.2.8)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.2->gcsfs) (0.4.8)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.7/dist-packages (from yarl<2.0,>=1.0->aiohttp<4->gcsfs) (2.10)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib->gcsfs) (1.3.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib->gcsfs) (3.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->gcsfs) (2022.5.18.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->gcsfs) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->gcsfs) (1.24.3)
# Requirement already satisfied: google-resumable-media<0.5.0dev,>=0.3.1 in /usr/local/lib/python3.7/dist-packages (from google-cloud-storage->gcsfs) (0.4.1)
# Requirement already satisfied: google-cloud-core<2.0dev,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from google-cloud-storage->gcsfs) (1.0.3)
# Requirement already satisfied: google-api-core<2.0.0dev,>=1.14.0 in /usr/local/lib/python3.7/dist-packages (from google-cloud-core<2.0dev,>=1.0.0->google-cloud-storage->gcsfs) (1.31.6)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.0->google-cloud-storage->gcsfs) (2022.1)
# Requirement already satisfied: protobuf<4.0.0dev,>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.0->google-cloud-storage->gcsfs) (3.17.3)
# Requirement already satisfied: packaging>=14.3 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.0->google-cloud-storage->gcsfs) (21.3)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.0->google-cloud-storage->gcsfs) (1.56.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=14.3->google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.0->google-cloud-storage->gcsfs) (3.0.9)
# Installing collected packages: multidict, frozenlist, yarl, asynctest, async-timeout, aiosignal, fsspec, aiohttp, gcsfs
# Successfully installed aiohttp-3.8.1 aiosignal-1.2.0 async-timeout-4.0.2 asynctest-0.13.0 frozenlist-1.3.0 fsspec-2022.5.0 gcsfs-2022.5.0 multidict-6.0.2 yarl-1.7.2

# %%
pip install pymongo
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pymongo in /usr/local/lib/python3.7/dist-packages (4.1.1)

# %%
pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (1.3.5)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (2022.1)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (1.21.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)

# %%
pip install pyspark
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyspark
#   Downloading pyspark-3.2.1.tar.gz (281.4 MB)
#      |████████████████████████████████| 281.4 MB 35 kB/s
# Collecting py4j==0.10.9.3
#   Downloading py4j-0.10.9.3-py2.py3-none-any.whl (198 kB)
#      |████████████████████████████████| 198 kB 50.8 MB/s
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.2.1-py2.py3-none-any.whl size=281853642 sha256=a1bf90e18bd6a29b53537e23b644bdf357ee0e18b531e7bfd2cf4f6b62c85860
#   Stored in directory: /root/.cache/pip/wheels/9f/f5/07/7cd8017084dce4e93e84e92efd1e1d5334db05f2e83bcef74f
# Successfully built pyspark
# Installing collected packages: py4j, pyspark
# Successfully installed py4j-0.10.9.3 pyspark-3.2.1

# %%
pip install fsspec
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: fsspec in /usr/local/lib/python3.7/dist-packages (2022.5.0)

# %%
pip install pandera
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pandera
#   Downloading pandera-0.9.0-py3-none-any.whl (197 kB)
#      |████████████████████████████████| 197 kB 5.0 MB/s
# Collecting pydantic
#   Downloading pydantic-1.9.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.1 MB)
#      |████████████████████████████████| 11.1 MB 46.6 MB/s
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from pandera) (1.21.6)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from pandera) (21.3)
# Requirement already satisfied: pandas>=1.0 in /usr/local/lib/python3.7/dist-packages (from pandera) (1.3.5)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.7/dist-packages (from pandera) (6.0.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.7/dist-packages (from pandera) (1.14.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from pandera) (4.2.0)
# Collecting typing-inspect>=0.6.0
#   Downloading typing_inspect-0.7.1-py3-none-any.whl (8.4 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->pandera) (3.0.9)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.0->pandera) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.0->pandera) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=1.0->pandera) (1.15.0)
# Collecting mypy-extensions>=0.3.0
#   Downloading mypy_extensions-0.4.3-py2.py3-none-any.whl (4.5 kB)
# Installing collected packages: mypy-extensions, typing-inspect, pydantic, pandera
# Successfully installed mypy-extensions-0.4.3 pandera-0.9.0 pydantic-1.9.1 typing-inspect-0.7.1

# %% [markdown]
# * psycopg2 -> Adaptador Postgres
# * requests -> Solicitações HTTP em Python
# * pymongo -> Conexão com o MongoDB
# * sqlalchemy -> Mapeamento Objeto Relacional
# * datetime -> fornece as classes para manipulação de datas e horas
# * csv -> ler e gravar arquivos .csv
# * collections -> trabalhar com dados de maneira eficiente
# * numpy -> processamento de grandes, multi-dimensionais arranjos e matrizes, juntamente com uma grande coleção de funções matemáticas de alto nível para operar sobre estas matrizes
# * pandera -> validação do schema

# %%
import psycopg2
import requests
import pymongo
import sqlalchemy
import datetime
import csv
import collections
import numpy as np
import pandera as pa
# Out:
# /usr/local/lib/python3.7/dist-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)

# %% [markdown]
# * Pandas -> análise e manipulação de dados
# * os -> automação de processos em Python
# * storage -> armazenamento em nuvem

# %%
import pandas as pd
import pyspark.sql.functions as F
from google.cloud import storage

# %%
import os

# %%
from pyspark.sql import SparkSession
from pyspark import SparkConf
from pyspark.sql.types import *
from pyspark.sql.window import Window
from pyspark.sql.functions import isnull, isnan, when, count, col
from pyspark.sql.functions import *
from pyspark.sql.functions import ceil, col

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ##**CONEXÃO GCP**

# %% [markdown]
# INCLUINDO A CHAVE DE SEGURANÇA DO GCP

# %%
serviceAccount = '/content/drive/MyDrive/projeto-final-the-last-dance-8b51b88868a6.json'

os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = serviceAccount

# %% [markdown]
# ACESSANDO O BUCKET

# %%
acesso = storage.Client()

bucket = acesso.get_bucket('projeto-final')

# %% [markdown]
# CRIANDO O DATAFRAME

# %%
bucket.blob('Mortalidade_Geral_2017.csv')
# Out:
# <Blob: projeto-final, Mortalidade_Geral_2017.csv, None>

# %%
path = 'gs://projeto-final/arq-original/Mortalidade_Geral_2017.csv'

# %% [markdown]
# CONVERTENDO ARQUIVO CID -> JSON EM CSV

# %%
df_cid = pd.read_json('gs://projeto-final/arq-original/cid10.json')

# %%
df_cid.codigo=df_cid.codigo.str.replace('.','')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.

# %%
df_cid.to_csv('gs://projeto-final/arq-original/cid10.csv', index=False)

# %% [markdown]
# ##**NORMALIZAÇÃO E TRATAMENTO COM PYSPARK**

# %% [markdown]
# CONEXÃO COM A SPARKSESSION

# %%
spark = ( SparkSession.builder
                        .master("local")
                        .appName("projeto-final")
                        .config("spark.ui.port", "4050")
                        .config("spark.jars", 'https://storage.googleapis.com/hadoop-lib/gcs/gcs-connector-hadoop2-latest.jar')
                        .getOrCreate() 
        )

# %%
spark_2017 = ( spark.read.format('csv')
                       .option('header', 'true')
                       .option('inferschema', 'true')
                       .option('delimiter', ';')
                       .load('gs://projeto-final/arq-original/Mortalidade_Geral_2017.csv')
)

# %%
df_cid1 = ( spark.read.format("csv")
                  .option("header", "true")
                  .option("inferschema", "true")
                  .option("delimiter", ",")
                  .load('gs://projeto-final/arq-original/cid10.csv')
)

# %%
df_uf1 = ( spark.read.format("csv")
                  .option("header", "true")
                  .option("inferschema", "true")
                  .option("delimiter", ",")
                  .load('gs://projeto-final/arq-original/Arquivos auxiliares/UF-Munic.csv')
)

# %% [markdown]
# PRÉ-ANALISE DOS DADOS -> DF SPARK_2017

# %%
spark_2017.count()
# Out:
# 1312663

# %%
spark_2017.dtypes
# Out:
# [('CONTADOR', 'int'),
#  ('ORIGEM', 'int'),
#  ('TIPOBITO', 'int'),
#  ('DTOBITO', 'int'),
#  ('HORAOBITO', 'int'),
#  ('NATURAL', 'int'),
#  ('CODMUNNATU', 'int'),
#  ('DTNASC', 'int'),
#  ('IDADE', 'int'),
#  ('SEXO', 'int'),
#  ('RACACOR', 'int'),
#  ('ESTCIV', 'int'),
#  ('ESC', 'int'),
#  ('ESC2010', 'int'),
#  ('SERIESCFAL', 'int'),
#  ('OCUP', 'int'),
#  ('CODMUNRES', 'int'),
#  ('LOCOCOR', 'int'),
#  ('CODESTAB', 'int'),
#  ('ESTABDESCR', 'string'),
#  ('CODMUNOCOR', 'int'),
#  ('IDADEMAE', 'int'),
#  ('ESCMAE', 'int'),
#  ('ESCMAE2010', 'int'),
#  ('SERIESCMAE', 'int'),
#  ('OCUPMAE', 'int'),
#  ('QTDFILVIVO', 'int'),
#  ('QTDFILMORT', 'int'),
#  ('GRAVIDEZ', 'int'),
#  ('SEMAGESTAC', 'int'),
#  ('GESTACAO', 'int'),
#  ('PARTO', 'int'),
#  ('OBITOPARTO', 'int'),
#  ('PESO', 'int'),
#  ('TPMORTEOCO', 'int'),
#  ('OBITOGRAV', 'int'),
#  ('OBITOPUERP', 'int'),
#  ('ASSISTMED', 'int'),
#  ('EXAME', 'int'),
#  ('CIRURGIA', 'int'),
#  ('NECROPSIA', 'int'),
#  ('LINHAA', 'string'),
#  ('LINHAB', 'string'),
#  ('LINHAC', 'string'),
#  ('LINHAD', 'string'),
#  ('LINHAII', 'string'),
#  ('CAUSABAS', 'string'),
#  ('CB_PRE', 'string'),
#  ('COMUNSVOIM', 'string'),
#  ('DTATESTADO', 'int'),
#  ('CIRCOBITO', 'int'),
#  ('ACIDTRAB', 'int'),
#  ('FONTE', 'int'),
#  ('NUMEROLOTE', 'int'),
#  ('TPPOS', 'string'),
#  ('DTINVESTIG', 'int'),
#  ('CAUSABAS_O', 'string'),
#  ('DTCADASTRO', 'int'),
#  ('ATESTANTE', 'int'),
#  ('STCODIFICA', 'string'),
#  ('CODIFICADO', 'string'),
#  ('VERSAOSIST', 'string'),
#  ('VERSAOSCB', 'double'),
#  ('FONTEINV', 'int'),
#  ('DTRECEBIM', 'int'),
#  ('ATESTADO', 'string'),
#  ('DTRECORIGA', 'int'),
#  ('CAUSAMAT', 'string'),
#  ('ESCMAEAGR1', 'int'),
#  ('ESCFALAGR1', 'int'),
#  ('STDOEPIDEM', 'int'),
#  ('STDONOVA', 'int'),
#  ('DIFDATA', 'int'),
#  ('NUDIASOBCO', 'int'),
#  ('NUDIASOBIN', 'string'),
#  ('DTCADINV', 'int'),
#  ('TPOBITOCOR', 'int'),
#  ('DTCONINV', 'int'),
#  ('FONTES', 'string'),
#  ('TPRESGINFO', 'int'),
#  ('TPNIVELINV', 'string'),
#  ('NUDIASINF', 'string'),
#  ('DTCADINF', 'int'),
#  ('MORTEPARTO', 'int'),
#  ('DTCONCASO', 'int'),
#  ('FONTESINF', 'string'),
#  ('ALTCAUSA', 'int')]

# %%
df_cid1.show()
# Out:
# +------+--------------------+
# |codigo|                nome|
# +------+--------------------+
# |   A00|              Cólera|
# |  A000|Cólera Devida a V...|
# |  A001|Cólera Devida a V...|
# |  A009|Cólera Não Especi...|
# |   A01|Febres Tifóide e ...|
# |  A010|       Febre Tifóide|
# |  A011| Febre Paratifóide A|
# |  A012| Febre Paratifóide B|
# |  A013| Febre Paratifóide C|
# |  A014|Febre Paratifóide...|
# |   A02|Outras Infecções ...|
# |  A020|Enterite Por Salm...|
# |  A021|Septicemia Por Sa...|
# |  A022|Infecções Localiz...|
# |  A028|Outras Infecções ...|
# |  A029|Infecção Não Espe...|
# |   A03|          Shiguelose|
# |  A030|Shiguelose Devida...|
# |  A031|Shiguelose Devida...|
# |  A032|Shiguelose Devida...|
# +------+--------------------+
# only showing top 20 rows

# %%
spark_2017.show(1)
# Out:
# +--------+------+--------+-------+---------+-------+----------+-------+-----+----+-------+------+---+-------+----------+----+---------+-------+--------+----------+----------+--------+------+----------+----------+-------+----------+----------+--------+----------+--------+-----+----------+----+----------+---------+----------+---------+-----+--------+---------+------+------+------+------+-------+--------+------+----------+----------+---------+--------+-----+----------+-----+----------+----------+----------+---------+----------+----------+----------+---------+--------+---------+--------+----------+--------+----------+----------+----------+--------+-------+----------+----------+--------+----------+--------+------+----------+----------+---------+--------+----------+---------+---------+--------+
# |CONTADOR|ORIGEM|TIPOBITO|DTOBITO|HORAOBITO|NATURAL|CODMUNNATU| DTNASC|IDADE|SEXO|RACACOR|ESTCIV|ESC|ESC2010|SERIESCFAL|OCUP|CODMUNRES|LOCOCOR|CODESTAB|ESTABDESCR|CODMUNOCOR|IDADEMAE|ESCMAE|ESCMAE2010|SERIESCMAE|OCUPMAE|QTDFILVIVO|QTDFILMORT|GRAVIDEZ|SEMAGESTAC|GESTACAO|PARTO|OBITOPARTO|PESO|TPMORTEOCO|OBITOGRAV|OBITOPUERP|ASSISTMED|EXAME|CIRURGIA|NECROPSIA|LINHAA|LINHAB|LINHAC|LINHAD|LINHAII|CAUSABAS|CB_PRE|COMUNSVOIM|DTATESTADO|CIRCOBITO|ACIDTRAB|FONTE|NUMEROLOTE|TPPOS|DTINVESTIG|CAUSABAS_O|DTCADASTRO|ATESTANTE|STCODIFICA|CODIFICADO|VERSAOSIST|VERSAOSCB|FONTEINV|DTRECEBIM|ATESTADO|DTRECORIGA|CAUSAMAT|ESCMAEAGR1|ESCFALAGR1|STDOEPIDEM|STDONOVA|DIFDATA|NUDIASOBCO|NUDIASOBIN|DTCADINV|TPOBITOCOR|DTCONINV|FONTES|TPRESGINFO|TPNIVELINV|NUDIASINF|DTCADINF|MORTEPARTO|DTCONCASO|FONTESINF|ALTCAUSA|
# +--------+------+--------+-------+---------+-------+----------+-------+-----+----+-------+------+---+-------+----------+----+---------+-------+--------+----------+----------+--------+------+----------+----------+-------+----------+----------+--------+----------+--------+-----+----------+----+----------+---------+----------+---------+-----+--------+---------+------+------+------+------+-------+--------+------+----------+----------+---------+--------+-----+----------+-----+----------+----------+----------+---------+----------+----------+----------+---------+--------+---------+--------+----------+--------+----------+----------+----------+--------+-------+----------+----------+--------+----------+--------+------+----------+----------+---------+--------+----------+---------+---------+--------+
# |       1|     1|       2|5092017|      700|    812|    120039|3031997|  420|   1|      5|  null|  3|      2|         6|null|   120039|      5|    null|      null|    120039|    null|  null|      null|      null|   null|      null|      null|    null|      null|    null| null|      null|null|      null|     null|      null|        2| null|    null|        2| *R58X|  null|  null|  null|   null|     R58|  null|      null|   6092017|     null|    null| null|      null| null|      null|      null|  22022018|        5|         N|         N|     2...0|     null|    null|     null|     R58|  22022018|    null|      null|         3|         0|       1|    170|      null|      null|    null|      null|    null|  null|      null|      null|     null|    null|      null|     null|     null|    null|
# +--------+------+--------+-------+---------+-------+----------+-------+-----+----+-------+------+---+-------+----------+----+---------+-------+--------+----------+----------+--------+------+----------+----------+-------+----------+----------+--------+----------+--------+-----+----------+----+----------+---------+----------+---------+-----+--------+---------+------+------+------+------+-------+--------+------+----------+----------+---------+--------+-----+----------+-----+----------+----------+----------+---------+----------+----------+----------+---------+--------+---------+--------+----------+--------+----------+----------+----------+--------+-------+----------+----------+--------+----------+--------+------+----------+----------+---------+--------+----------+---------+---------+--------+
# only showing top 1 row

# %%
#CONTANDO OS CAMPOS "NULL" DE CADA COLUNA DO DF
spark_2017.select([count(when(isnull(c), c)).alias(c) for c in spark_2017.columns]).show()
# Out:
# +--------+------+--------+-------+---------+-------+----------+------+-----+----+-------+------+------+-------+----------+------+---------+-------+--------+----------+----------+--------+-------+----------+----------+-------+----------+----------+--------+----------+--------+-------+----------+-------+----------+---------+----------+---------+-------+--------+---------+------+------+------+-------+-------+--------+-------+----------+----------+---------+--------+-------+----------+------+----------+----------+----------+---------+----------+----------+----------+---------+--------+---------+--------+----------+--------+----------+----------+----------+--------+-------+----------+----------+--------+----------+--------+-------+----------+----------+---------+--------+----------+---------+---------+--------+
# |CONTADOR|ORIGEM|TIPOBITO|DTOBITO|HORAOBITO|NATURAL|CODMUNNATU|DTNASC|IDADE|SEXO|RACACOR|ESTCIV|   ESC|ESC2010|SERIESCFAL|  OCUP|CODMUNRES|LOCOCOR|CODESTAB|ESTABDESCR|CODMUNOCOR|IDADEMAE| ESCMAE|ESCMAE2010|SERIESCMAE|OCUPMAE|QTDFILVIVO|QTDFILMORT|GRAVIDEZ|SEMAGESTAC|GESTACAO|  PARTO|OBITOPARTO|   PESO|TPMORTEOCO|OBITOGRAV|OBITOPUERP|ASSISTMED|  EXAME|CIRURGIA|NECROPSIA|LINHAA|LINHAB|LINHAC| LINHAD|LINHAII|CAUSABAS| CB_PRE|COMUNSVOIM|DTATESTADO|CIRCOBITO|ACIDTRAB|  FONTE|NUMEROLOTE| TPPOS|DTINVESTIG|CAUSABAS_O|DTCADASTRO|ATESTANTE|STCODIFICA|CODIFICADO|VERSAOSIST|VERSAOSCB|FONTEINV|DTRECEBIM|ATESTADO|DTRECORIGA|CAUSAMAT|ESCMAEAGR1|ESCFALAGR1|STDOEPIDEM|STDONOVA|DIFDATA|NUDIASOBCO|NUDIASOBIN|DTCADINV|TPOBITOCOR|DTCONINV| FONTES|TPRESGINFO|TPNIVELINV|NUDIASINF|DTCADINF|MORTEPARTO|DTCONCASO|FONTESINF|ALTCAUSA|
# +--------+------+--------+-------+---------+-------+----------+------+-----+----+-------+------+------+-------+----------+------+---------+-------+--------+----------+----------+--------+-------+----------+----------+-------+----------+----------+--------+----------+--------+-------+----------+-------+----------+---------+----------+---------+-------+--------+---------+------+------+------+-------+-------+--------+-------+----------+----------+---------+--------+-------+----------+------+----------+----------+----------+---------+----------+----------+----------+---------+--------+---------+--------+----------+--------+----------+----------+----------+--------+-------+----------+----------+--------+----------+--------+-------+----------+----------+---------+--------+----------+---------+---------+--------+
# |       0|     0|       0|      0|    66661|  93387|    112447|  4422|    0|   0|  40646| 84013|126576| 134902|   1069702|239184|        0|      0|  363975|   1312663|         0| 1280159|1280603|   1280762|   1300142|1283921|   1280523|   1281914| 1279129|   1281529| 1281369|1279302|   1279608|1280478|   1230329|  1229988|   1230029|   395588|1308668| 1308725|   373966| 39971|296470|674960|1039455| 856959|       0|1312663|   1058846|     15119|  1153584| 1266211|1181199|       142|462698|   1096994|      1173|      5464|   127354|       239|         1|         1|    71960| 1091559|      178|       0|         0| 1312640|   1280762|    134902|        21|       0|      0|   1254480|   1312663| 1253969|   1253969| 1254571|1221741|   1309495|   1253877|  1312663| 1280521|   1280521|  1283206|  1312663| 1281781|
# +--------+------+--------+-------+---------+-------+----------+------+-----+----+-------+------+------+-------+----------+------+---------+-------+--------+----------+----------+--------+-------+----------+----------+-------+----------+----------+--------+----------+--------+-------+----------+-------+----------+---------+----------+---------+-------+--------+---------+------+------+------+-------+-------+--------+-------+----------+----------+---------+--------+-------+----------+------+----------+----------+----------+---------+----------+----------+----------+---------+--------+---------+--------+----------+--------+----------+----------+----------+--------+-------+----------+----------+--------+----------+--------+-------+----------+----------+---------+--------+----------+---------+---------+--------+

# %% [markdown]
# DROPANDO COLUNAS QUE NÃO SERÃO UTILIZADAS

# %%
spark_2017 = spark_2017.drop(*('ORIGEM','HORAOBITO','ESTCIV','ESC','ESC2010','SERIESCFAL','CODMUNRES','IDADEMAE','ESCMAE','ESCMAE2010','SERIESCMAE','OCUPMAE','QTDFILMORT','GRAVIDEZ','SEMAGESTAC','GESTACAO','PARTO','OBITOPARTO','PESO','TPMORTEOCO','ASSISTMED','EXAME','CIRURGIA','NECROPSIA','CB_PRE','COMUNSVOIM','DTATESTADO','ACIDTRAB','NUMEROLOTE','DTINVESTIG','DTCADASTRO','ATESTANTE','STCODIFICA','CODIFICADO','VERSAOSIST','VERSAOSCB','FONTEINV','DTRECEBIM','ATESTADO','DTRECORIGA','CAUSAMAT','ESCMAEAGR1','ESCFALAGR1','DTCADINV','DTCONINV','FONTES','TPRESGINFO','TPNIVELINV','DTCADINF','MORTEPARTO','DTCONCASO','ALTCAUSA','TPPOS','TP_ALTERA','CB_ALT','CIRCOBITO','FONTE','NUDIASOBCO','TPOBITOCOR','QTDFILVIVO','OBITOGRAV','OBITOPUERP','LINHAA','LINHAB','LINHAC','LINHAD','LINHAII','IDADE','NUDIASOBIN', 'NUDIASINF', 'FONTESINF','ESTABDESCR','NATURAL','CODMUNNATU','DIFDATA','CONTADOR'))

# %%
spark_2017.show(5)
# Out:
# +--------+--------+--------+----+-------+------+-------+--------+----------+--------+----------+----------+--------+
# |TIPOBITO| DTOBITO|  DTNASC|SEXO|RACACOR|  OCUP|LOCOCOR|CODESTAB|CODMUNOCOR|CAUSABAS|CAUSABAS_O|STDOEPIDEM|STDONOVA|
# +--------+--------+--------+----+-------+------+-------+--------+----------+--------+----------+----------+--------+
# |       2| 5092017| 3031997|   1|      5|  null|      5|    null|    120039|     R58|      null|         0|       1|
# |       2|11022017| 9022017|   1|      4|  null|      1| 2000733|    120040|    P000|      P000|         0|       1|
# |       2|11022017|13071933|   2|      4|999993|      1| 2001578|    120040|    I694|      I694|         0|       1|
# |       2|11022017| 6022002|   1|      4|  null|      3|    null|    120040|    G809|       R99|         0|       1|
# |       2|11022017| 2061966|   2|      4|622020|      1| 2001578|    120040|    E119|      E119|         0|       1|
# +--------+--------+--------+----+-------+------+-------+--------+----------+--------+----------+----------+--------+
# only showing top 5 rows

# %% [markdown]
# COMANDO PARA RENOMEAR COLUNAS

# %%
spark_2017 = spark_2017.withColumnRenamed("contador", "SEQUENCIA").withColumnRenamed("TIPOBITO", "TIPO_OBITO").withColumnRenamed("DTOBITO", "DATA_OBITO").withColumnRenamed("RACACOR", "RACA_COR").withColumnRenamed("OCUP", "OCUPACAO").withColumnRenamed("LOCOCOR", "LOCAL_OCORRENCIA").withColumnRenamed("CODESTAB", "COD_ESTABELECIMENTO").withColumnRenamed("CODMUNOCOR", "CIDADE_OBITO").withColumnRenamed("CAUSABAS", "CAUSA_OBITO").withColumnRenamed("STDOEPIDEM", "STATUS_D_OEPIDEM").withColumnRenamed("STDONOVA", "STATUS_D_O_NOVA")

# %%
df_cid1 = df_cid1.withColumnRenamed("codigo","CAUSA_OBITO")

# %%
spark_2017.show(5)
# Out:
# +----------+----------+--------+----+--------+--------+----------------+-------------------+------------+-----------+----------+----------------+---------------+
# |TIPO_OBITO|DATA_OBITO|  DTNASC|SEXO|RACA_COR|OCUPACAO|LOCAL_OCORRENCIA|COD_ESTABELECIMENTO|CIDADE_OBITO|CAUSA_OBITO|CAUSABAS_O|STATUS_D_OEPIDEM|STATUS_D_O_NOVA|
# +----------+----------+--------+----+--------+--------+----------------+-------------------+------------+-----------+----------+----------------+---------------+
# |         2|   5092017| 3031997|   1|       5|    null|               5|               null|      120039|        R58|      null|               0|              1|
# |         2|  11022017| 9022017|   1|       4|    null|               1|            2000733|      120040|       P000|      P000|               0|              1|
# |         2|  11022017|13071933|   2|       4|  999993|               1|            2001578|      120040|       I694|      I694|               0|              1|
# |         2|  11022017| 6022002|   1|       4|    null|               3|               null|      120040|       G809|       R99|               0|              1|
# |         2|  11022017| 2061966|   2|       4|  622020|               1|            2001578|      120040|       E119|      E119|               0|              1|
# +----------+----------+--------+----+--------+--------+----------------+-------------------+------------+-----------+----------+----------------+---------------+
# only showing top 5 rows

# %%
#CONTANDO OS CAMPOS "NULL" DE CADA COLUNA DO DF
spark_2017.select([count(when(isnull(c), c)).alias(c) for c in spark_2017.columns]).show()
# Out:
# +----------+----------+------+----+--------+--------+----------------+-------------------+------------+-----------+----------+----------------+---------------+
# |TIPO_OBITO|DATA_OBITO|DTNASC|SEXO|RACA_COR|OCUPACAO|LOCAL_OCORRENCIA|COD_ESTABELECIMENTO|CIDADE_OBITO|CAUSA_OBITO|CAUSABAS_O|STATUS_D_OEPIDEM|STATUS_D_O_NOVA|
# +----------+----------+------+----+--------+--------+----------------+-------------------+------------+-----------+----------+----------------+---------------+
# |         0|         0|  4422|   0|   40646|  239184|               0|             363975|           0|          0|      1173|              21|              0|
# +----------+----------+------+----+--------+--------+----------------+-------------------+------------+-----------+----------+----------------+---------------+

# %%
#JOIN DE DATAFRAMES
df_inner_2017 = spark_2017.join(df_cid1, on=['CAUSA_OBITO'], how='left')

# %%
#RENOMEANDO COLUNA RECEM CRIADA
df_inner_2017 = df_inner_2017.withColumnRenamed("nome","DESCRICAO_OBITO")

# %%
#VERIFICANDO QUANTAS COLUNAS TEM O DF
print(len(df_inner_2017.columns))
# Out:
# 14

# %%
#CRIAÇÃO DE COLUNA PARA CONTAGEM DOS OBITOS
df_inner_2017 = df_inner_2017.withColumn('QTD_OBITO',F.lit(1))

# %%
#FAZENDO BACKUP DO DF
df2017 = df_inner_2017

# %%
df2017.show(5)
# Out:
# +-----------+----------+----------+--------+----+--------+--------+----------------+-------------------+------------+----------+----------------+---------------+--------------------+---------+
# |CAUSA_OBITO|TIPO_OBITO|DATA_OBITO|  DTNASC|SEXO|RACA_COR|OCUPACAO|LOCAL_OCORRENCIA|COD_ESTABELECIMENTO|CIDADE_OBITO|CAUSABAS_O|STATUS_D_OEPIDEM|STATUS_D_O_NOVA|     DESCRICAO_OBITO|QTD_OBITO|
# +-----------+----------+----------+--------+----+--------+--------+----------------+-------------------+------------+----------+----------------+---------------+--------------------+---------+
# |        R58|         2|   5092017| 3031997|   1|       5|    null|               5|               null|      120039|      null|               0|              1|Hemorragia Não Cl...|        1|
# |       P000|         2|  11022017| 9022017|   1|       4|    null|               1|            2000733|      120040|      P000|               0|              1|Feto e Recém-nasc...|        1|
# |       I694|         2|  11022017|13071933|   2|       4|  999993|               1|            2001578|      120040|      I694|               0|              1|Seqüelas de Acide...|        1|
# |       G809|         2|  11022017| 6022002|   1|       4|    null|               3|               null|      120040|       R99|               0|              1|Paralisia Cerebra...|        1|
# |       E119|         2|  11022017| 2061966|   2|       4|  622020|               1|            2001578|      120040|      E119|               0|              1|Diabetes Mellitus...|        1|
# +-----------+----------+----------+--------+----+--------+--------+----------------+-------------------+------------+----------+----------------+---------------+--------------------+---------+
# only showing top 5 rows

# %% [markdown]
# REALIZANDO O TRATAMENTO DAS DATAS

# %%
df2017 = df2017.withColumn('DATA_OBITO', lpad(df2017.DATA_OBITO,8, '0')).withColumn('DTNASC', lpad(df2017.DTNASC,8, '0'))

# %%
df2017.show(5)
# Out:
# +-----------+----------+----------+--------+----+--------+--------+----------------+-------------------+------------+----------+----------------+---------------+--------------------+---------+
# |CAUSA_OBITO|TIPO_OBITO|DATA_OBITO|  DTNASC|SEXO|RACA_COR|OCUPACAO|LOCAL_OCORRENCIA|COD_ESTABELECIMENTO|CIDADE_OBITO|CAUSABAS_O|STATUS_D_OEPIDEM|STATUS_D_O_NOVA|     DESCRICAO_OBITO|QTD_OBITO|
# +-----------+----------+----------+--------+----+--------+--------+----------------+-------------------+------------+----------+----------------+---------------+--------------------+---------+
# |        R58|         2|  05092017|03031997|   1|       5|    null|               5|               null|      120039|      null|               0|              1|Hemorragia Não Cl...|        1|
# |       P000|         2|  11022017|09022017|   1|       4|    null|               1|            2000733|      120040|      P000|               0|              1|Feto e Recém-nasc...|        1|
# |       I694|         2|  11022017|13071933|   2|       4|  999993|               1|            2001578|      120040|      I694|               0|              1|Seqüelas de Acide...|        1|
# |       G809|         2|  11022017|06022002|   1|       4|    null|               3|               null|      120040|       R99|               0|              1|Paralisia Cerebra...|        1|
# |       E119|         2|  11022017|02061966|   2|       4|  622020|               1|            2001578|      120040|      E119|               0|              1|Diabetes Mellitus...|        1|
# +-----------+----------+----------+--------+----+--------+--------+----------------+-------------------+------------+----------+----------------+---------------+--------------------+---------+
# only showing top 5 rows

# %%
df2017 = df2017.withColumn("DATA_OBITO", F.to_date(F.col("DATA_OBITO").cast("string"), 'ddMMyyyy')).withColumn("DTNASC", F.to_date(F.col("DTNASC").cast("string"), 'ddMMyyyy'))

# %%
df2017.show(5)
# Out:
# +-----------+----------+----------+----------+----+--------+--------+----------------+-------------------+------------+----------+----------------+---------------+--------------------+---------+
# |CAUSA_OBITO|TIPO_OBITO|DATA_OBITO|    DTNASC|SEXO|RACA_COR|OCUPACAO|LOCAL_OCORRENCIA|COD_ESTABELECIMENTO|CIDADE_OBITO|CAUSABAS_O|STATUS_D_OEPIDEM|STATUS_D_O_NOVA|     DESCRICAO_OBITO|QTD_OBITO|
# +-----------+----------+----------+----------+----+--------+--------+----------------+-------------------+------------+----------+----------------+---------------+--------------------+---------+
# |        R58|         2|2017-09-05|1997-03-03|   1|       5|    null|               5|               null|      120039|      null|               0|              1|Hemorragia Não Cl...|        1|
# |       P000|         2|2017-02-11|2017-02-09|   1|       4|    null|               1|            2000733|      120040|      P000|               0|              1|Feto e Recém-nasc...|        1|
# |       I694|         2|2017-02-11|1933-07-13|   2|       4|  999993|               1|            2001578|      120040|      I694|               0|              1|Seqüelas de Acide...|        1|
# |       G809|         2|2017-02-11|2002-02-06|   1|       4|    null|               3|               null|      120040|       R99|               0|              1|Paralisia Cerebra...|        1|
# |       E119|         2|2017-02-11|1966-06-02|   2|       4|  622020|               1|            2001578|      120040|      E119|               0|              1|Diabetes Mellitus...|        1|
# +-----------+----------+----------+----------+----+--------+--------+----------------+-------------------+------------+----------+----------------+---------------+--------------------+---------+
# only showing top 5 rows

# %% [markdown]
# CALCULANDO A IDADE EM QUE OCORRERAM OS OBITOS

# %%
#MONTHS_BETWEEN() - RETORNA A DIFERENÇA ENTRE DUAS DATAS EM MESES
from pyspark.sql.functions import *
df2017.select(F.col('DTNASC'), F.col('DATA_OBITO'), F.months_between(F.col('DATA_OBITO'), F.col('DTNASC')).alias('IDADE')).show()
# Out:
# +----------+----------+-------------+
# |    DTNASC|DATA_OBITO|        IDADE|
# +----------+----------+-------------+
# |1997-03-03|2017-09-05| 246.06451613|
# |2017-02-09|2017-02-11|   0.06451613|
# |1933-07-13|2017-02-11|1002.93548387|
# |2002-02-06|2017-02-11| 180.16129032|
# |1966-06-02|2017-02-11| 608.29032258|
# |1946-12-28|2017-02-11|  841.4516129|
# |1955-12-04|2017-02-10| 734.19354839|
# |1943-10-03|2017-02-10| 880.22580645|
# |2017-02-06|2017-02-10|   0.12903226|
# |2017-01-14|2017-02-09|   0.83870968|
# |1931-07-20|2017-02-09|1026.64516129|
# |2017-02-09|2017-02-09|          0.0|
# |2017-02-09|2017-02-09|          0.0|
# |1968-04-17|2017-02-09| 585.74193548|
# |1940-11-25|2017-02-09| 914.48387097|
# |1922-02-20|2017-02-10|1139.67741935|
# |1942-12-01|2017-06-29| 894.90322581|
# |1932-04-02|2017-06-29|1022.87096774|
# |1934-03-02|2017-07-01| 999.96774194|
# |1961-09-14|2017-06-30| 669.51612903|
# +----------+----------+-------------+
# only showing top 20 rows

# %%
df2017 = df2017.withColumn('IDADE', F.months_between(F.col('DATA_OBITO'), F.col('DTNASC')))

# %%
from pyspark.sql.functions import ceil, col
df2017 = df2017.select("*",ceil("IDADE"))

# %%
df2017 = df2017.withColumn('IDADE_COMPLETA',((col('CEIL(IDADE)') / 12)))

# %%
from pyspark.sql.functions import ceil, col
df2017 = df2017.select("*",ceil("IDADE_COMPLETA"))

# %%
df2017 = df2017.drop('IDADE')

# %%
df2017 = df2017.drop('CEIL(IDADE)')

# %%
df2017 = df2017.drop('IDADE_COMPLETA')

# %%
#COMANDO PARA RENOMEAR COLUNAS
df2017 = df2017.withColumnRenamed("CEIL(IDADE_COMPLETA)", "IDADE_OBITO")

# %%
df2017.show(5)
# Out:
# +-----------+----------+----------+----------+----+--------+--------+----------------+-------------------+------------+----------+----------------+---------------+--------------------+---------+-----------+
# |CAUSA_OBITO|TIPO_OBITO|DATA_OBITO|    DTNASC|SEXO|RACA_COR|OCUPACAO|LOCAL_OCORRENCIA|COD_ESTABELECIMENTO|CIDADE_OBITO|CAUSABAS_O|STATUS_D_OEPIDEM|STATUS_D_O_NOVA|     DESCRICAO_OBITO|QTD_OBITO|IDADE_OBITO|
# +-----------+----------+----------+----------+----+--------+--------+----------------+-------------------+------------+----------+----------------+---------------+--------------------+---------+-----------+
# |        R58|         2|2017-09-05|1997-03-03|   1|       5|    null|               5|               null|      120039|      null|               0|              1|Hemorragia Não Cl...|        1|         21|
# |       P000|         2|2017-02-11|2017-02-09|   1|       4|    null|               1|            2000733|      120040|      P000|               0|              1|Feto e Recém-nasc...|        1|          1|
# |       I694|         2|2017-02-11|1933-07-13|   2|       4|  999993|               1|            2001578|      120040|      I694|               0|              1|Seqüelas de Acide...|        1|         84|
# |       G809|         2|2017-02-11|2002-02-06|   1|       4|    null|               3|               null|      120040|       R99|               0|              1|Paralisia Cerebra...|        1|         16|
# |       E119|         2|2017-02-11|1966-06-02|   2|       4|  622020|               1|            2001578|      120040|      E119|               0|              1|Diabetes Mellitus...|        1|         51|
# +-----------+----------+----------+----------+----+--------+--------+----------------+-------------------+------------+----------+----------------+---------------+--------------------+---------+-----------+
# only showing top 5 rows

# %% [markdown]
# INFORMANDO OS ESTADOS EM QUE OCORRERAM OS OBITOS
#
# Estas informações foram obtidas no dataset uf1

# %%
df2017 = df2017.withColumn('ESTADO_DA_OCORRENCIA', F.when((F.col('CIDADE_OBITO') > 310000) & (F.col('CIDADE_OBITO') < 319999), F.lit('Minas Gerais'))
                                              .when((F.col('CIDADE_OBITO') > 110000) & (F.col('CIDADE_OBITO') < 119999), F.lit('Rondônia'))
                                              .when((F.col('CIDADE_OBITO') > 120000) & (F.col('CIDADE_OBITO') < 129999), F.lit('Acre'))
                                              .when((F.col('CIDADE_OBITO') > 130000) & (F.col('CIDADE_OBITO') < 139999), F.lit('Amazonia'))
                                              .when((F.col('CIDADE_OBITO') > 140000) & (F.col('CIDADE_OBITO') < 149999), F.lit('Roraiama'))
                                              .when((F.col('CIDADE_OBITO') > 150000) & (F.col('CIDADE_OBITO') < 159999), F.lit('Pará'))
                                              .when((F.col('CIDADE_OBITO') > 160000) & (F.col('CIDADE_OBITO') < 169999), F.lit('Amapá'))
                                              .when((F.col('CIDADE_OBITO') > 170000) & (F.col('CIDADE_OBITO') < 179999), F.lit('Tocantins'))
                                              .when((F.col('CIDADE_OBITO') > 210000) & (F.col('CIDADE_OBITO') < 219999), F.lit('Maranhão'))
                                              .when((F.col('CIDADE_OBITO') > 220000) & (F.col('CIDADE_OBITO') < 229999), F.lit('Piauí'))
                                              .when((F.col('CIDADE_OBITO') > 230000) & (F.col('CIDADE_OBITO') < 239999), F.lit('Ceará'))
                                              .when((F.col('CIDADE_OBITO') > 240000) & (F.col('CIDADE_OBITO') < 249999), F.lit('Rio Grande do Norte'))
                                              .when((F.col('CIDADE_OBITO') > 250000) & (F.col('CIDADE_OBITO') < 259999), F.lit('Paraíba'))
                                              .when((F.col('CIDADE_OBITO') > 260000) & (F.col('CIDADE_OBITO') < 269999), F.lit('Pernambuco'))
                                              .when((F.col('CIDADE_OBITO') > 270000) & (F.col('CIDADE_OBITO') < 279999), F.lit('Alagoas'))
                                              .when((F.col('CIDADE_OBITO') > 280000) & (F.col('CIDADE_OBITO') < 289999), F.lit('Sergipe'))
                                              .when((F.col('CIDADE_OBITO') > 290000) & (F.col('CIDADE_OBITO') < 299999), F.lit('Bahia'))
                                              .when((F.col('CIDADE_OBITO') > 320000) & (F.col('CIDADE_OBITO') < 329999), F.lit('Espirito Santo'))
                                              .when((F.col('CIDADE_OBITO') > 330000) & (F.col('CIDADE_OBITO') < 339999), F.lit('Rio de Janeiro'))
                                              .when((F.col('CIDADE_OBITO') > 350000) & (F.col('CIDADE_OBITO') < 359999), F.lit('São Paulo'))
                                              .when((F.col('CIDADE_OBITO') > 410000) & (F.col('CIDADE_OBITO') < 419999), F.lit('Paraná'))
                                              .when((F.col('CIDADE_OBITO') > 420000) & (F.col('CIDADE_OBITO') < 429999), F.lit('Santa Catarina'))
                                              .when((F.col('CIDADE_OBITO') > 430000) & (F.col('CIDADE_OBITO') < 439999), F.lit('Rio Grande do Sul'))
                                              .when((F.col('CIDADE_OBITO') > 500000) & (F.col('CIDADE_OBITO') < 509999), F.lit('Mato Grosso do Sul'))
                                              .when((F.col('CIDADE_OBITO') > 510000) & (F.col('CIDADE_OBITO') < 519999), F.lit('Mato Grosso'))
                                              .when((F.col('CIDADE_OBITO') > 520000) & (F.col('CIDADE_OBITO') < 529999), F.lit('Goiás'))
                                              .when((F.col('CIDADE_OBITO') > 530000) & (F.col('CIDADE_OBITO') < 539999), F.lit('DF'))
                                              .otherwise(F.lit('Não Informado')))

# %%
df2017.show(10)
# Out:
# +-----------+----------+----------+----------+----+--------+--------+----------------+-------------------+------------+----------+----------------+---------------+--------------------+---------+-----------+--------------------+
# |CAUSA_OBITO|TIPO_OBITO|DATA_OBITO|    DTNASC|SEXO|RACA_COR|OCUPACAO|LOCAL_OCORRENCIA|COD_ESTABELECIMENTO|CIDADE_OBITO|CAUSABAS_O|STATUS_D_OEPIDEM|STATUS_D_O_NOVA|     DESCRICAO_OBITO|QTD_OBITO|IDADE_OBITO|ESTADO_DA_OCORRENCIA|
# +-----------+----------+----------+----------+----+--------+--------+----------------+-------------------+------------+----------+----------------+---------------+--------------------+---------+-----------+--------------------+
# |        R58|         2|2017-09-05|1997-03-03|   1|       5|    null|               5|               null|      120039|      null|               0|              1|Hemorragia Não Cl...|        1|         21|                Acre|
# |       P000|         2|2017-02-11|2017-02-09|   1|       4|    null|               1|            2000733|      120040|      P000|               0|              1|Feto e Recém-nasc...|        1|          1|                Acre|
# |       I694|         2|2017-02-11|1933-07-13|   2|       4|  999993|               1|            2001578|      120040|      I694|               0|              1|Seqüelas de Acide...|        1|         84|                Acre|
# |       G809|         2|2017-02-11|2002-02-06|   1|       4|    null|               3|               null|      120040|       R99|               0|              1|Paralisia Cerebra...|        1|         16|                Acre|
# |       E119|         2|2017-02-11|1966-06-02|   2|       4|  622020|               1|            2001578|      120040|      E119|               0|              1|Diabetes Mellitus...|        1|         51|                Acre|
# |       C920|         2|2017-02-11|1946-12-28|   2|       4|    null|               1|            2001578|      120040|      C920|               0|              1|Leucemia Mielóide...|        1|         71|                Acre|
# |       C349|         2|2017-02-10|1955-12-04|   1|       4|  622020|               1|            2001586|      120040|      C349|               0|              1|Neoplasia Maligna...|        1|         62|                Acre|
# |        C73|         2|2017-02-10|1943-10-03|   2|       1|    null|               1|            2001586|      120040|       C73|               0|              1|Neoplasia Maligna...|        1|         74|                Acre|
# |       P369|         2|2017-02-10|2017-02-06|   1|       4|    null|               1|            2000733|      120040|      P000|               0|              1|Septicemia Bacter...|        1|          1|                Acre|
# |       Q870|         2|2017-02-09|2017-01-14|   2|    null|    null|               1|            2000385|      120040|      Q870|               0|              1|Síndromes Com Mal...|        1|          1|                Acre|
# +-----------+----------+----------+----------+----+--------+--------+----------------+-------------------+------------+----------+----------------+---------------+--------------------+---------+-----------+--------------------+
# only showing top 10 rows

# %% [markdown]
# RENOMEANDO INFORMAÇÕES DAS COLUNAS RACA_COR, LOCAL_OCORRENCIA E SEXO

# %%
df2017 = df2017.withColumn('RACA_COR', F.regexp_replace('RACA_COR','1','Branca')).withColumn('RACA_COR', F.regexp_replace('RACA_COR','2','Preta')).withColumn('RACA_COR', F.regexp_replace('RACA_COR','3','Amarela')).withColumn('RACA_COR', F.regexp_replace('RACA_COR','4','Parda')).withColumn('RACA_COR', F.regexp_replace('RACA_COR','5','Indigena'))

# %%
df2017 = df2017.withColumn('LOCAL_OCORRENCIA', F.regexp_replace('LOCAL_OCORRENCIA','1','Hospital')).withColumn('LOCAL_OCORRENCIA', F.regexp_replace('LOCAL_OCORRENCIA','2','Outros estabelecimentos de saúde')).withColumn('LOCAL_OCORRENCIA', F.regexp_replace('LOCAL_OCORRENCIA','3','Domicílio')).withColumn('LOCAL_OCORRENCIA', F.regexp_replace('LOCAL_OCORRENCIA','4','Via pública')).withColumn('LOCAL_OCORRENCIA', F.regexp_replace('LOCAL_OCORRENCIA','5','Outros')).withColumn('LOCAL_OCORRENCIA', F.regexp_replace('LOCAL_OCORRENCIA','6','Aldeia indígena')).withColumn('LOCAL_OCORRENCIA', F.regexp_replace('LOCAL_OCORRENCIA','9','Ignorado'))

# %%
df2017 = df2017.withColumn('SEXO', F.regexp_replace('SEXO','0','N/I')).withColumn('SEXO', F.regexp_replace('SEXO','1','Masc')).withColumn('SEXO', F.regexp_replace('SEXO','2','Fem'))

# %%
df2017 = df2017.drop('CAUSABAS_O')

# %%
df2017.show(5)
# Out:
# +-----------+----------+----------+----------+----+--------+--------+----------------+-------------------+------------+----------------+---------------+--------------------+---------+-----------+--------------------+
# |CAUSA_OBITO|TIPO_OBITO|DATA_OBITO|    DTNASC|SEXO|RACA_COR|OCUPACAO|LOCAL_OCORRENCIA|COD_ESTABELECIMENTO|CIDADE_OBITO|STATUS_D_OEPIDEM|STATUS_D_O_NOVA|     DESCRICAO_OBITO|QTD_OBITO|IDADE_OBITO|ESTADO_DA_OCORRENCIA|
# +-----------+----------+----------+----------+----+--------+--------+----------------+-------------------+------------+----------------+---------------+--------------------+---------+-----------+--------------------+
# |        R58|         2|2017-09-05|1997-03-03|Masc|Indigena|    null|          Outros|               null|      120039|               0|              1|Hemorragia Não Cl...|        1|         21|                Acre|
# |       P000|         2|2017-02-11|2017-02-09|Masc|   Parda|    null|        Hospital|            2000733|      120040|               0|              1|Feto e Recém-nasc...|        1|          1|                Acre|
# |       I694|         2|2017-02-11|1933-07-13| Fem|   Parda|  999993|        Hospital|            2001578|      120040|               0|              1|Seqüelas de Acide...|        1|         84|                Acre|
# |       G809|         2|2017-02-11|2002-02-06|Masc|   Parda|    null|       Domicílio|               null|      120040|               0|              1|Paralisia Cerebra...|        1|         16|                Acre|
# |       E119|         2|2017-02-11|1966-06-02| Fem|   Parda|  622020|        Hospital|            2001578|      120040|               0|              1|Diabetes Mellitus...|        1|         51|                Acre|
# +-----------+----------+----------+----------+----+--------+--------+----------------+-------------------+------------+----------------+---------------+--------------------+---------+-----------+--------------------+
# only showing top 5 rows

# %%
df2017.select('SEXO').distinct().collect()
# Out:
# [Row(SEXO='Fem'), Row(SEXO='N/I'), Row(SEXO='Masc')]

# %%
print(len(df2017.columns))
# Out:
# 16

# %% [markdown]
# Inclusão de coluna por:
# * Jovens - Indivíduos de até 19 anos;
# * Adultos - Indivíduos com idade entre 20 até 59 anos;
# * Idosos - Indivíduos de 60 anos em diante.

# %%
df2017 = (df2017.withColumn('IDADE', F.when((F.col('IDADE_OBITO') <= 19), F.lit('Jovem'))
                             .when((F.col('IDADE_OBITO') > 19) & (F.col('IDADE_OBITO') <= 59), F.lit('Adulto'))
                             .when((F.col('IDADE_OBITO') > 59), F.lit('Idoso')))
)

# %%
df2017.show(5)
# Out:
# +-----------+----------+----------+----------+----+--------+--------+----------------+-------------------+------------+----------------+---------------+--------------------+---------+-----------+--------------------+------+
# |CAUSA_OBITO|TIPO_OBITO|DATA_OBITO|    DTNASC|SEXO|RACA_COR|OCUPACAO|LOCAL_OCORRENCIA|COD_ESTABELECIMENTO|CIDADE_OBITO|STATUS_D_OEPIDEM|STATUS_D_O_NOVA|     DESCRICAO_OBITO|QTD_OBITO|IDADE_OBITO|ESTADO_DA_OCORRENCIA| IDADE|
# +-----------+----------+----------+----------+----+--------+--------+----------------+-------------------+------------+----------------+---------------+--------------------+---------+-----------+--------------------+------+
# |        R58|         2|2017-09-05|1997-03-03|Masc|Indigena|    null|          Outros|               null|      120039|               0|              1|Hemorragia Não Cl...|        1|         21|                Acre|Adulto|
# |       P000|         2|2017-02-11|2017-02-09|Masc|   Parda|    null|        Hospital|            2000733|      120040|               0|              1|Feto e Recém-nasc...|        1|          1|                Acre| Jovem|
# |       I694|         2|2017-02-11|1933-07-13| Fem|   Parda|  999993|        Hospital|            2001578|      120040|               0|              1|Seqüelas de Acide...|        1|         84|                Acre| Idoso|
# |       G809|         2|2017-02-11|2002-02-06|Masc|   Parda|    null|       Domicílio|               null|      120040|               0|              1|Paralisia Cerebra...|        1|         16|                Acre| Jovem|
# |       E119|         2|2017-02-11|1966-06-02| Fem|   Parda|  622020|        Hospital|            2001578|      120040|               0|              1|Diabetes Mellitus...|        1|         51|                Acre|Adulto|
# +-----------+----------+----------+----------+----+--------+--------+----------------+-------------------+------------+----------------+---------------+--------------------+---------+-----------+--------------------+------+
# only showing top 5 rows

# %% [markdown]
# ##**NORMALIZAÇÃO E TRATAMENTO COM PANDAS**

# %% [markdown]
# Convertendo df spark para pandas

# %%
df_pandas = df2017.toPandas()

# %%
df_pandas.head(1)
# Out:
#   CAUSA_OBITO  TIPO_OBITO  DATA_OBITO      DTNASC  SEXO  RACA_COR  OCUPACAO  \
# 0         R58           2  2017-09-05  1997-03-03  Masc  Indigena       NaN
#
#   LOCAL_OCORRENCIA  COD_ESTABELECIMENTO  CIDADE_OBITO  STATUS_D_OEPIDEM  \
# 0           Outros                  NaN        120039               0.0
#
#    STATUS_D_O_NOVA                             DESCRICAO_OBITO  QTD_OBITO  \
# 0                1  Hemorragia Não Classificada em Outra Parte          1
#
#    IDADE_OBITO ESTADO_DA_OCORRENCIA   IDADE
# 0         21.0                 Acre  Adulto

# %%
df_pandas.isnull().sum()
# Out:
# CAUSA_OBITO                  0
# TIPO_OBITO                   0
# DATA_OBITO                   0
# DTNASC                    4422
# SEXO                         0
# RACA_COR                 40646
# OCUPACAO                239184
# LOCAL_OCORRENCIA             0
# COD_ESTABELECIMENTO     363975
# CIDADE_OBITO                 0
# STATUS_D_OEPIDEM            21
# STATUS_D_O_NOVA              0
# DESCRICAO_OBITO              0
# QTD_OBITO                    0
# IDADE_OBITO               4422
# ESTADO_DA_OCORRENCIA         0
# IDADE                     4422
# dtype: int64

# %% [markdown]
# SUBSTITUINDO OS CAMPOS NULL

# %%
df_pandas['DTNASC'].fillna(0, inplace=True)
df_pandas['RACA_COR'].fillna('Não Informado', inplace=True)
df_pandas['OCUPACAO'].fillna(0, inplace=True)
df_pandas['COD_ESTABELECIMENTO'].fillna(0, inplace=True)
df_pandas['STATUS_D_OEPIDEM'].fillna('Não Informado', inplace=True)
df_pandas['IDADE_OBITO'].fillna(0, inplace=True)

# %%
df_pandas.dtypes
# Out:
# CAUSA_OBITO              object
# TIPO_OBITO                int32
# DATA_OBITO               object
# DTNASC                   object
# SEXO                     object
# RACA_COR                 object
# OCUPACAO                float64
# LOCAL_OCORRENCIA         object
# COD_ESTABELECIMENTO     float64
# CIDADE_OBITO              int32
# STATUS_D_OEPIDEM         object
# STATUS_D_O_NOVA           int32
# DESCRICAO_OBITO          object
# QTD_OBITO                 int32
# IDADE_OBITO             float64
# ESTADO_DA_OCORRENCIA     object
# IDADE                    object
# dtype: object

# %%
df_pandas.head(1)
# Out:
#   CAUSA_OBITO  TIPO_OBITO  DATA_OBITO      DTNASC  SEXO  RACA_COR  OCUPACAO  \
# 0         R58           2  2017-09-05  1997-03-03  Masc  Indigena       0.0
#
#   LOCAL_OCORRENCIA  COD_ESTABELECIMENTO  CIDADE_OBITO STATUS_D_OEPIDEM  \
# 0           Outros                  0.0        120039              0.0
#
#    STATUS_D_O_NOVA                             DESCRICAO_OBITO  QTD_OBITO  \
# 0                1  Hemorragia Não Classificada em Outra Parte          1
#
#    IDADE_OBITO ESTADO_DA_OCORRENCIA   IDADE
# 0         21.0                 Acre  Adulto

# %% [markdown]
# CONSTRUÇÃO DO SCHEMA

# %%
schema = pa.DataFrameSchema(
    columns = {
        "CAUSA_OBITO":pa.Column(pa.String),
        "TIPO_OBITO":pa.Column(pa.Int32),
        "DATA_OBITO":pa.Column(pa.String),
        "DTNASC":pa.Column(pa.String),
        "SEXO":pa.Column(pa.String),
        "RACA_COR":pa.Column(pa.String),
        "OCUPACAO":pa.Column(pa.Float64),
        "LOCAL_OCORRENCIA":pa.Column(pa.String),
        "COD_ESTABELECIMENTO":pa.Column(pa.Float64),
        "CIDADE_OBITO":pa.Column(pa.Int32),
        "STATUS_D_OEPIDEM":pa.Column(pa.String),
        "STATUS_D_O_NOVA":pa.Column(pa.Int32),
        "DESCRICAO_OBITO":pa.Column(pa.String),
        "QTD_OBITO":pa.Column(pa.Int32),
        "IDADE_OBITO":pa.Column(pa.Float64),
        "ESTADO_DA_OCORRENCIA":pa.Column(pa.String)
            
          }
    
)

# %%
df_pandas.dtypes
# Out:
# CAUSA_OBITO              object
# TIPO_OBITO                int32
# DATA_OBITO               object
# DTNASC                   object
# SEXO                     object
# RACA_COR                 object
# OCUPACAO                float64
# LOCAL_OCORRENCIA         object
# COD_ESTABELECIMENTO     float64
# CIDADE_OBITO              int32
# STATUS_D_OEPIDEM         object
# STATUS_D_O_NOVA           int32
# DESCRICAO_OBITO          object
# QTD_OBITO                 int32
# IDADE_OBITO             float64
# ESTADO_DA_OCORRENCIA     object
# IDADE                    object
# dtype: object

# %%
schema.validate(df_pandas)
# Out:
#         CAUSA_OBITO  TIPO_OBITO  DATA_OBITO      DTNASC  SEXO  RACA_COR  \
# 0               R58           2  2017-09-05  1997-03-03  Masc  Indigena
# 1              P000           2  2017-02-11  2017-02-09  Masc     Parda
# 2              I694           2  2017-02-11  1933-07-13   Fem     Parda
# 3              G809           2  2017-02-11  2002-02-06  Masc     Parda
# 4              E119           2  2017-02-11  1966-06-02   Fem     Parda
# ...             ...         ...         ...         ...   ...       ...
# 1312658        X950           2  2017-12-25  1982-05-02  Masc     Parda
# 1312659        C229           2  2017-10-26  1937-05-01  Masc     Parda
# 1312660        X954           2  2017-12-14  1996-08-01  Masc     Parda
# 1312661        I509           2  2017-10-01  1932-04-08  Masc     Parda
# 1312662        X954           2  2017-12-28  1994-04-20  Masc     Parda
#
#          OCUPACAO LOCAL_OCORRENCIA  COD_ESTABELECIMENTO  CIDADE_OBITO  \
# 0             0.0           Outros                  0.0        120039
# 1             0.0         Hospital            2000733.0        120040
# 2        999993.0         Hospital            2001578.0        120040
# 3             0.0        Domicílio                  0.0        120040
# 4        622020.0         Hospital            2001578.0        120040
# ...           ...              ...                  ...           ...
# 1312658  354705.0        Domicílio                  0.0        170210
# 1312659  999993.0        Domicílio                  0.0        171070
# 1312660  999991.0      Via pública                  0.0        170210
# 1312661  999993.0        Domicílio                  0.0        171070
# 1312662       0.0      Via pública                  0.0        170930
#
#         STATUS_D_OEPIDEM  STATUS_D_O_NOVA  \
# 0                    0.0                1
# 1                    0.0                1
# 2                    0.0                1
# 3                    0.0                1
# 4                    0.0                1
# ...                  ...              ...
# 1312658    Não Informado                1
# 1312659    Não Informado                1
# 1312660    Não Informado                1
# 1312661    Não Informado                1
# 1312662    Não Informado                1
#
#                                            DESCRICAO_OBITO  QTD_OBITO  \
# 0               Hemorragia Não Classificada em Outra Parte          1
# 1        Feto e Recém-nascido Afetados Por Transtornos ...          1
# 2        Seqüelas de Acidente Vascular Cerebral Não Esp...          1
# 3                      Paralisia Cerebral Não Especificada          1
# 4        Diabetes Mellitus Não-insulino-dependente - Se...          1
# ...                                                    ...        ...
# 1312658  Agressão Por Meio de Disparo de Outra Arma de ...          1
# 1312659      Neoplasia Maligna do Fígado, Não Especificada          1
# 1312660  Agressão Por Meio de Disparo de Outra Arma de ...          1
# 1312661            Insuficiência Cardíaca Não Especificada          1
# 1312662  Agressão Por Meio de Disparo de Outra Arma de ...          1
#
#          IDADE_OBITO ESTADO_DA_OCORRENCIA   IDADE
# 0               21.0                 Acre  Adulto
# 1                1.0                 Acre   Jovem
# 2               84.0                 Acre   Idoso
# 3               16.0                 Acre   Jovem
# 4               51.0                 Acre  Adulto
# ...              ...                  ...     ...
# 1312658         36.0            Tocantins  Adulto
# 1312659         81.0            Tocantins   Idoso
# 1312660         22.0            Tocantins  Adulto
# 1312661         86.0            Tocantins   Idoso
# 1312662         24.0            Tocantins  Adulto
#
# [1312663 rows x 17 columns]

# %% [markdown]
# CONSTRUÇÃO DOS INSIGHTS PANDAS

# %%
df_pandas.head(1)
# Out:
#   CAUSA_OBITO  TIPO_OBITO  DATA_OBITO      DTNASC  SEXO  RACA_COR  OCUPACAO  \
# 0         R58           2  2017-09-05  1997-03-03  Masc  Indigena       0.0
#
#   LOCAL_OCORRENCIA  COD_ESTABELECIMENTO  CIDADE_OBITO STATUS_D_OEPIDEM  \
# 0           Outros                  0.0        120039              0.0
#
#    STATUS_D_O_NOVA                             DESCRICAO_OBITO  QTD_OBITO  \
# 0                1  Hemorragia Não Classificada em Outra Parte          1
#
#    IDADE_OBITO ESTADO_DA_OCORRENCIA   IDADE
# 0         21.0                 Acre  Adulto

# %%
df_pandas.groupby(['RACA_COR']).size().sort_values(ascending=False)
# Out:
# RACA_COR
# Branca           663147
# Parda            497839
# Preta             99745
# Não Informado     40646
# Amarela            7375
# Indigena           3911
# dtype: int64

# %%
df_pandas.groupby(['SEXO']).size().sort_values(ascending=False)
# Out:
# SEXO
# Masc    734469
# Fem     577573
# N/I        621
# dtype: int64

# %%
df_pandas.groupby(['IDADE']).size().sort_values(ascending=False)
# Out:
# IDADE
# Idoso     894720
# Adulto    347844
# Jovem      65677
# dtype: int64

# %%
df_pandas.groupby(['IDADE','SEXO','RACA_COR','LOCAL_OCORRENCIA','DESCRICAO_OBITO']).size().sort_values(ascending=False).head(10)
# Out:
# IDADE   SEXO  RACA_COR  LOCAL_OCORRENCIA  DESCRICAO_OBITO
# Idoso   Fem   Branca    Hospital          Pneumonia Não Especificada                                                                       12781
# Adulto  Masc  Parda     Via pública       Agressão Por Meio de Disparo de Outra Arma de Fogo ou de Arma Não Especificada -Rua e Estrada    11060
# Idoso   Masc  Branca    Hospital          Infarto Agudo do Miocárdio Não Especificado                                                      10775
#                                           Pneumonia Não Especificada                                                                       10151
#         Fem   Branca    Hospital          Infarto Agudo do Miocárdio Não Especificado                                                       9576
#         Masc  Branca    Domicílio         Infarto Agudo do Miocárdio Não Especificado                                                       7175
#               Parda     Hospital          Infarto Agudo do Miocárdio Não Especificado                                                       6747
#               Branca    Hospital          Neoplasia Maligna Dos Brônquios ou Pulmões, Não Especificado                                      6469
#         Fem   Branca    Hospital          Infecção do Trato Urinário de Localização Não Especificada                                        6015
#                         Domicílio         Infarto Agudo do Miocárdio Não Especificado                                                       5797
# dtype: int64

# %% [markdown]
# ##**GRAFICOS**

# %%
df_pandas.groupby(['ESTADO_DA_OCORRENCIA']).size().sort_values(ascending=False).plot.bar(figsize=(10,8),xlabel = 'ESTADO_DA_OCORRENCIA', ylabel= 'QTD_OBITO')

# %%
df_pandas.groupby(['LOCAL_OCORRENCIA']).size().sort_values(ascending=False).plot.bar(figsize=(10,8),xlabel = 'LOCAL_OCORRENCIA', ylabel= 'QTD_OBITO')

# %%
df_pandas.groupby(['IDADE']).size().sort_values(ascending=False).plot.bar(figsize=(10,8),xlabel = 'IDADE', ylabel= 'QTD_OBITO')

# %% [markdown]
# ##**CONVERTENDO DATAFRAME EM CSV E ENVIANDO PARA O BUCKET**

# %%
#df_pandas.to_csv('gs://projeto-final/tratados/df_2017.csv', index=False)
